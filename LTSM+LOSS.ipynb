# %%
from math import sqrt
from numpy import concatenate
from matplotlib import pyplot
from pandas import read_csv
from pandas import DataFrame
from pandas import concat
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_error
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
import sys
import time

def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
	n_vars = 1 if type(data) is list else data.shape[1]
	df = DataFrame(data)
	cols, names = list(), list()
	# input sequence (t-n, ... t-1)
	for i in range(n_in, 0, -1):
		cols.append(df.shift(i))
		names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
	# forecast sequence (t, t+1, ... t+n)
	for i in range(0, n_out):
		cols.append(df.shift(-i))
		if i == 0:
			names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
		else:
			names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
	# put it all together
	agg = concat(cols, axis=1)
	agg.columns = names
	# drop rows with NaN values
	if dropnan:
		agg.dropna(inplace=True)
	return agg
 
# load dataset
dataset = read_csv('alya_formatted_2.csv', header=0, index_col=0)
values = dataset.values

n_days_predict=5
n_features=5


# ensure all data is float
values = values.astype('float64')

# normalize features
scaler = MinMaxScaler(feature_range=(0, 1))
scaled = scaler.fit_transform(values)

# frame as supervised learning
reframed = series_to_supervised(scaled, n_days_predict, 1)


# split into train and test sets
values = reframed.values
n_train_set = 2100
train = values[:n_train_set, :]
test = values[n_train_set:, :]

# split into input and outputs
n_obs = n_days_predict * n_features
train_X, train_y = train[:, :n_obs], train[:, -n_features]
test_X, test_y = test[:, :n_obs], test[:, -n_features]

#print(train_X.shape, len(train_X), train_y.shape)

# reshape input to be 3D [samples, timesteps, features]
train_X = train_X.reshape((train_X.shape[0], 1, train_X.shape[1]))
test_X = test_X.reshape((test_X.shape[0], 1, test_X.shape[1]))

#print shape of tensors
#print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
print ('Training set:')
print (len(train_X))
print ('Test set: ')
print (len(test_X))

# design network
model = Sequential()
model.add(LSTM(50, input_shape=(train_X.shape[1], train_X.shape[2])))
model.add(Dense(1))
model.compile(loss='mae', optimizer='adam')

# fit network
history = model.fit(train_X, train_y, epochs=300, batch_size=50, validation_data=(test_X, test_y), verbose=2, shuffle=False)

# plot history
# pyplot.plot(history.history['loss'], label='train')
# pyplot.plot(history.history['val_loss'], label='test')
# pyplot.title('LSTM Loss')
# pyplot.xlabel('epochs')
# pyplot.ylabel('loss')
# pyplot.legend()
# pyplot.show()
 
# make a prediction
yhat = model.predict(test_X)
test_X = test_X.reshape((test_X.shape[0], test_X.shape[2]))

# invert scaling for forecast
inv_yhat = concatenate((yhat, test_X[:, -4:]), axis=1)
inv_yhat = scaler.inverse_transform(inv_yhat)
inv_yhat = inv_yhat[:,0]
# invert scaling for actual
test_y = test_y.reshape((len(test_y), 1))
inv_y = concatenate((test_y, test_X[:, -4:]), axis=1)
inv_y = scaler.inverse_transform(inv_y)
inv_y = inv_y[:,0]

# calculate RMS 
rmse = sqrt(mean_squared_error(inv_y, inv_yhat))
print('Test RMSE: %.3f' % rmse)
# pyplot.legend()
# pyplot.show()

# pyplot.plot(test_y, color = 'red', label = 'Real price')
# pyplot.plot(inv_yhat, color= 'blue', label = 'predicted price')

# pyplot.title('price prediction')
# pyplot.xlabel('days')
# pyplot.ylabel('price')
# pyplot.legend()
# pyplot.show()
# Out:
# Training set:
# 2100
# Test set:
# 881
# Train on 2100 samples, validate on 881 samples
# Epoch 1/300
#  - 1s - loss: 0.0984 - val_loss: 0.2487
# Epoch 2/300
#  - 0s - loss: 0.0638 - val_loss: 0.2232
# Epoch 3/300
#  - 0s - loss: 0.0529 - val_loss: 0.1788
# Epoch 4/300
#  - 0s - loss: 0.0423 - val_loss: 0.1305
# Epoch 5/300
#  - 0s - loss: 0.0340 - val_loss: 0.0829
# Epoch 6/300
#  - 0s - loss: 0.0241 - val_loss: 0.0208
# Epoch 7/300
#  - 0s - loss: 0.0116 - val_loss: 0.0331
# Epoch 8/300
#  - 0s - loss: 0.0175 - val_loss: 0.0641
# Epoch 9/300
#  - 0s - loss: 0.0218 - val_loss: 0.0162
# Epoch 10/300
#  - 0s - loss: 0.0103 - val_loss: 0.0334
# Epoch 11/300
#  - 0s - loss: 0.0175 - val_loss: 0.0633
# Epoch 12/300
#  - 0s - loss: 0.0215 - val_loss: 0.0154
# Epoch 13/300
#  - 0s - loss: 0.0101 - val_loss: 0.0319
# Epoch 14/300
#  - 0s - loss: 0.0169 - val_loss: 0.0616
# Epoch 15/300
#  - 0s - loss: 0.0211 - val_loss: 0.0150
# Epoch 16/300
#  - 0s - loss: 0.0097 - val_loss: 0.0304
# Epoch 17/300
#  - 0s - loss: 0.0162 - val_loss: 0.0598
# Epoch 18/300
#  - 0s - loss: 0.0208 - val_loss: 0.0148
# Epoch 19/300
#  - 0s - loss: 0.0096 - val_loss: 0.0311
# Epoch 20/300
#  - 0s - loss: 0.0167 - val_loss: 0.0549
# Epoch 21/300
#  - 0s - loss: 0.0197 - val_loss: 0.0149
# Epoch 22/300
#  - 0s - loss: 0.0094 - val_loss: 0.0152
# Epoch 23/300
#  - 0s - loss: 0.0110 - val_loss: 0.0244
# Epoch 24/300
#  - 0s - loss: 0.0144 - val_loss: 0.0606
# Epoch 25/300
#  - 0s - loss: 0.0206 - val_loss: 0.0148
# Epoch 26/300
#  - 0s - loss: 0.0090 - val_loss: 0.0288
# Epoch 27/300
#  - 0s - loss: 0.0149 - val_loss: 0.0547
# Epoch 28/300
#  - 0s - loss: 0.0195 - val_loss: 0.0143
# Epoch 29/300
#  - 0s - loss: 0.0088 - val_loss: 0.0226
# Epoch 30/300
#  - 0s - loss: 0.0132 - val_loss: 0.0605
# Epoch 31/300
#  - 0s - loss: 0.0203 - val_loss: 0.0158
# Epoch 32/300
#  - 0s - loss: 0.0085 - val_loss: 0.0142
# Epoch 33/300
#  - 0s - loss: 0.0103 - val_loss: 0.0327
# Epoch 34/300
#  - 0s - loss: 0.0161 - val_loss: 0.0458
# Epoch 35/300
#  - 0s - loss: 0.0166 - val_loss: 0.0137
# Epoch 36/300
#  - 0s - loss: 0.0088 - val_loss: 0.0142
# Epoch 37/300
#  - 0s - loss: 0.0104 - val_loss: 0.0285
# Epoch 38/300
#  - 0s - loss: 0.0131 - val_loss: 0.0570
# Epoch 39/300
#  - 0s - loss: 0.0191 - val_loss: 0.0149
# Epoch 40/300
#  - 0s - loss: 0.0081 - val_loss: 0.0171
# Epoch 41/300
#  - 0s - loss: 0.0103 - val_loss: 0.0273
# Epoch 42/300
#  - 0s - loss: 0.0124 - val_loss: 0.0569
# Epoch 43/300
#  - 0s - loss: 0.0191 - val_loss: 0.0158
# Epoch 44/300
#  - 0s - loss: 0.0079 - val_loss: 0.0131
# Epoch 45/300
#  - 1s - loss: 0.0096 - val_loss: 0.0275
# Epoch 46/300
#  - 0s - loss: 0.0126 - val_loss: 0.0550
# Epoch 47/300
#  - 0s - loss: 0.0183 - val_loss: 0.0150
# Epoch 48/300
#  - 0s - loss: 0.0078 - val_loss: 0.0150
# Epoch 49/300
#  - 0s - loss: 0.0096 - val_loss: 0.0258
# Epoch 50/300
#  - 0s - loss: 0.0124 - val_loss: 0.0557
# Epoch 51/300
#  - 0s - loss: 0.0181 - val_loss: 0.0150
# Epoch 52/300
#  - 0s - loss: 0.0077 - val_loss: 0.0138
# Epoch 53/300
#  - 0s - loss: 0.0093 - val_loss: 0.0306
# Epoch 54/300
#  - 0s - loss: 0.0143 - val_loss: 0.0518
# Epoch 55/300
#  - 0s - loss: 0.0162 - val_loss: 0.0133
# Epoch 56/300
#  - 0s - loss: 0.0084 - val_loss: 0.0123
# Epoch 57/300
#  - 0s - loss: 0.0084 - val_loss: 0.0124
# Epoch 58/300
#  - 0s - loss: 0.0085 - val_loss: 0.0172
# Epoch 59/300
#  - 0s - loss: 0.0094 - val_loss: 0.0295
# Epoch 60/300
#  - 0s - loss: 0.0131 - val_loss: 0.0561
# Epoch 61/300
#  - 0s - loss: 0.0168 - val_loss: 0.0144
# Epoch 62/300
#  - 0s - loss: 0.0074 - val_loss: 0.0261
# Epoch 63/300
#  - 0s - loss: 0.0112 - val_loss: 0.0536
# Epoch 64/300
#  - 0s - loss: 0.0178 - val_loss: 0.0184
# Epoch 65/300
#  - 0s - loss: 0.0073 - val_loss: 0.0151
# Epoch 66/300
#  - 0s - loss: 0.0086 - val_loss: 0.0328
# Epoch 67/300
#  - 0s - loss: 0.0152 - val_loss: 0.0437
# Epoch 68/300
#  - 0s - loss: 0.0132 - val_loss: 0.0158
# Epoch 69/300
#  - 0s - loss: 0.0088 - val_loss: 0.0278
# Epoch 70/300
#  - 0s - loss: 0.0117 - val_loss: 0.0541
# Epoch 71/300
#  - 0s - loss: 0.0169 - val_loss: 0.0152
# Epoch 72/300
#  - 0s - loss: 0.0071 - val_loss: 0.0191
# Epoch 73/300
#  - 0s - loss: 0.0089 - val_loss: 0.0354
# Epoch 74/300
#  - 0s - loss: 0.0151 - val_loss: 0.0378
# Epoch 75/300
#  - 0s - loss: 0.0116 - val_loss: 0.0339
# Epoch 76/300
#  - 0s - loss: 0.0146 - val_loss: 0.0371
# Epoch 77/300
#  - 0s - loss: 0.0115 - val_loss: 0.0319
# Epoch 78/300
#  - 0s - loss: 0.0137 - val_loss: 0.0394
# Epoch 79/300
#  - 0s - loss: 0.0128 - val_loss: 0.0171
# Epoch 80/300
#  - 0s - loss: 0.0080 - val_loss: 0.0230
# Epoch 81/300
#  - 0s - loss: 0.0105 - val_loss: 0.0502
# Epoch 82/300
#  - 0s - loss: 0.0165 - val_loss: 0.0164
# Epoch 83/300
#  - 0s - loss: 0.0071 - val_loss: 0.0121
# Epoch 84/300
#  - 0s - loss: 0.0079 - val_loss: 0.0124
# Epoch 85/300
#  - 0s - loss: 0.0083 - val_loss: 0.0130
# Epoch 86/300
#  - 0s - loss: 0.0076 - val_loss: 0.0151
# Epoch 87/300
#  - 0s - loss: 0.0071 - val_loss: 0.0259
# Epoch 88/300
#  - 0s - loss: 0.0100 - val_loss: 0.0542
# Epoch 89/300
#  - 0s - loss: 0.0176 - val_loss: 0.0242
# Epoch 90/300
#  - 0s - loss: 0.0078 - val_loss: 0.0367
# Epoch 91/300
#  - 0s - loss: 0.0128 - val_loss: 0.0390
# Epoch 92/300
#  - 0s - loss: 0.0122 - val_loss: 0.0386
# Epoch 93/300
#  - 0s - loss: 0.0126 - val_loss: 0.0363
# Epoch 94/300
#  - 0s - loss: 0.0120 - val_loss: 0.0360
# Epoch 95/300
#  - 0s - loss: 0.0123 - val_loss: 0.0381
# Epoch 96/300
#  - 0s - loss: 0.0121 - val_loss: 0.0329
# Epoch 97/300
#  - 0s - loss: 0.0117 - val_loss: 0.0375
# Epoch 98/300
#  - 0s - loss: 0.0123 - val_loss: 0.0323
# Epoch 99/300
#  - 0s - loss: 0.0113 - val_loss: 0.0388
# Epoch 100/300
#  - 0s - loss: 0.0134 - val_loss: 0.0277
# Epoch 101/300
#  - 0s - loss: 0.0091 - val_loss: 0.0447
# Epoch 102/300
#  - 0s - loss: 0.0155 - val_loss: 0.0201
# Epoch 103/300
#  - 0s - loss: 0.0079 - val_loss: 0.0315
# Epoch 104/300
#  - 0s - loss: 0.0112 - val_loss: 0.0385
# Epoch 105/300
#  - 0s - loss: 0.0128 - val_loss: 0.0256
# Epoch 106/300
#  - 0s - loss: 0.0086 - val_loss: 0.0447
# Epoch 107/300
#  - 0s - loss: 0.0154 - val_loss: 0.0213
# Epoch 108/300
#  - 0s - loss: 0.0076 - val_loss: 0.0297
# Epoch 109/300
#  - 0s - loss: 0.0111 - val_loss: 0.0415
# Epoch 110/300
#  - 0s - loss: 0.0143 - val_loss: 0.0183
# Epoch 111/300
#  - 0s - loss: 0.0066 - val_loss: 0.0153
# Epoch 112/300
#  - 0s - loss: 0.0068 - val_loss: 0.0233
# Epoch 113/300
#  - 0s - loss: 0.0096 - val_loss: 0.0501
# Epoch 114/300
#  - 0s - loss: 0.0158 - val_loss: 0.0204
# Epoch 115/300
#  - 0s - loss: 0.0077 - val_loss: 0.0364
# Epoch 116/300
#  - 0s - loss: 0.0123 - val_loss: 0.0299
# Epoch 117/300
#  - 0s - loss: 0.0103 - val_loss: 0.0447
# Epoch 118/300
#  - 0s - loss: 0.0150 - val_loss: 0.0209
# Epoch 119/300
#  - 0s - loss: 0.0076 - val_loss: 0.0328
# Epoch 120/300
#  - 0s - loss: 0.0115 - val_loss: 0.0336
# Epoch 121/300
#  - 0s - loss: 0.0111 - val_loss: 0.0330
# Epoch 122/300
#  - 0s - loss: 0.0116 - val_loss: 0.0325
# Epoch 123/300
#  - 0s - loss: 0.0109 - val_loss: 0.0341
# Epoch 124/300
#  - 0s - loss: 0.0115 - val_loss: 0.0319
# Epoch 125/300
#  - 0s - loss: 0.0105 - val_loss: 0.0339
# Epoch 126/300
#  - 0s - loss: 0.0116 - val_loss: 0.0293
# Epoch 127/300
#  - 0s - loss: 0.0101 - val_loss: 0.0373
# Epoch 128/300
#  - 0s - loss: 0.0138 - val_loss: 0.0210
# Epoch 129/300
#  - 0s - loss: 0.0073 - val_loss: 0.0240
# Epoch 130/300
#  - 0s - loss: 0.0089 - val_loss: 0.0421
# Epoch 131/300
#  - 0s - loss: 0.0148 - val_loss: 0.0214
# Epoch 132/300
#  - 0s - loss: 0.0072 - val_loss: 0.0246
# Epoch 133/300
#  - 0s - loss: 0.0092 - val_loss: 0.0433
# Epoch 134/300
#  - 0s - loss: 0.0145 - val_loss: 0.0198
# Epoch 135/300
#  - 0s - loss: 0.0073 - val_loss: 0.0298
# Epoch 136/300
#  - 0s - loss: 0.0109 - val_loss: 0.0344
# Epoch 137/300
#  - 0s - loss: 0.0112 - val_loss: 0.0283
# Epoch 138/300
#  - 0s - loss: 0.0101 - val_loss: 0.0377
# Epoch 139/300
#  - 0s - loss: 0.0134 - val_loss: 0.0183
# Epoch 140/300
#  - 0s - loss: 0.0065 - val_loss: 0.0146
# Epoch 141/300
#  - 0s - loss: 0.0065 - val_loss: 0.0174
# Epoch 142/300
#  - 0s - loss: 0.0071 - val_loss: 0.0227
# Epoch 143/300
#  - 0s - loss: 0.0098 - val_loss: 0.0449
# Epoch 144/300
#  - 0s - loss: 0.0140 - val_loss: 0.0179
# Epoch 145/300
#  - 0s - loss: 0.0065 - val_loss: 0.0158
# Epoch 146/300
#  - 0s - loss: 0.0067 - val_loss: 0.0230
# Epoch 147/300
#  - 0s - loss: 0.0096 - val_loss: 0.0439
# Epoch 148/300
#  - 0s - loss: 0.0143 - val_loss: 0.0184
# Epoch 149/300
#  - 0s - loss: 0.0065 - val_loss: 0.0148
# Epoch 150/300
#  - 0s - loss: 0.0066 - val_loss: 0.0197
# Epoch 151/300
#  - 0s - loss: 0.0086 - val_loss: 0.0409
# Epoch 152/300
#  - 0s - loss: 0.0150 - val_loss: 0.0231
# Epoch 153/300
#  - 0s - loss: 0.0070 - val_loss: 0.0242
# Epoch 154/300
#  - 0s - loss: 0.0084 - val_loss: 0.0419
# Epoch 155/300
#  - 0s - loss: 0.0155 - val_loss: 0.0242
# Epoch 156/300
#  - 0s - loss: 0.0070 - val_loss: 0.0263
# Epoch 157/300
#  - 0s - loss: 0.0089 - val_loss: 0.0416
# Epoch 158/300
#  - 0s - loss: 0.0151 - val_loss: 0.0246
# Epoch 159/300
#  - 0s - loss: 0.0071 - val_loss: 0.0289
# Epoch 160/300
#  - 0s - loss: 0.0099 - val_loss: 0.0381
# Epoch 161/300
#  - 0s - loss: 0.0133 - val_loss: 0.0225
# Epoch 162/300
#  - 0s - loss: 0.0069 - val_loss: 0.0305
# Epoch 163/300
#  - 0s - loss: 0.0109 - val_loss: 0.0315
# Epoch 164/300
#  - 0s - loss: 0.0106 - val_loss: 0.0295
# Epoch 165/300
#  - 0s - loss: 0.0105 - val_loss: 0.0353
# Epoch 166/300
#  - 0s - loss: 0.0114 - val_loss: 0.0242
# Epoch 167/300
#  - 0s - loss: 0.0083 - val_loss: 0.0392
# Epoch 168/300
#  - 0s - loss: 0.0144 - val_loss: 0.0215
# Epoch 169/300
#  - 0s - loss: 0.0069 - val_loss: 0.0242
# Epoch 170/300
#  - 0s - loss: 0.0084 - val_loss: 0.0373
# Epoch 171/300
#  - 0s - loss: 0.0141 - val_loss: 0.0237
# Epoch 172/300
#  - 0s - loss: 0.0071 - val_loss: 0.0260
# Epoch 173/300
#  - 0s - loss: 0.0091 - val_loss: 0.0373
# Epoch 174/300
#  - 0s - loss: 0.0138 - val_loss: 0.0227
# Epoch 175/300
#  - 0s - loss: 0.0067 - val_loss: 0.0228
# Epoch 176/300
#  - 0s - loss: 0.0081 - val_loss: 0.0352
# Epoch 177/300
#  - 0s - loss: 0.0131 - val_loss: 0.0265
# Epoch 178/300
#  - 0s - loss: 0.0078 - val_loss: 0.0321
# Epoch 179/300
#  - 0s - loss: 0.0113 - val_loss: 0.0263
# Epoch 180/300
#  - 0s - loss: 0.0089 - val_loss: 0.0374
# Epoch 181/300
#  - 0s - loss: 0.0139 - val_loss: 0.0205
# Epoch 182/300
#  - 0s - loss: 0.0068 - val_loss: 0.0234
# Epoch 183/300
#  - 0s - loss: 0.0081 - val_loss: 0.0350
# Epoch 184/300
#  - 0s - loss: 0.0130 - val_loss: 0.0243
# Epoch 185/300
#  - 0s - loss: 0.0073 - val_loss: 0.0295
# Epoch 186/300
#  - 0s - loss: 0.0103 - val_loss: 0.0275
# Epoch 187/300
#  - 0s - loss: 0.0097 - val_loss: 0.0320
# Epoch 188/300
#  - 0s - loss: 0.0112 - val_loss: 0.0236
# Epoch 189/300
#  - 0s - loss: 0.0082 - val_loss: 0.0351
# Epoch 190/300
#  - 0s - loss: 0.0136 - val_loss: 0.0210
# Epoch 191/300
#  - 0s - loss: 0.0068 - val_loss: 0.0196
# Epoch 192/300
#  - 0s - loss: 0.0066 - val_loss: 0.0224
# Epoch 193/300
#  - 0s - loss: 0.0088 - val_loss: 0.0351
# Epoch 194/300
#  - 0s - loss: 0.0127 - val_loss: 0.0181
# Epoch 195/300
#  - 0s - loss: 0.0068 - val_loss: 0.0232
# Epoch 196/300
#  - 0s - loss: 0.0089 - val_loss: 0.0379
# Epoch 197/300
#  - 0s - loss: 0.0137 - val_loss: 0.0184
# Epoch 198/300
#  - 0s - loss: 0.0069 - val_loss: 0.0243
# Epoch 199/300
#  - 0s - loss: 0.0086 - val_loss: 0.0334
# Epoch 200/300
#  - 0s - loss: 0.0127 - val_loss: 0.0229
# Epoch 201/300
#  - 0s - loss: 0.0071 - val_loss: 0.0267
# Epoch 202/300
#  - 0s - loss: 0.0097 - val_loss: 0.0285
# Epoch 203/300
#  - 0s - loss: 0.0102 - val_loss: 0.0275
# Epoch 204/300
#  - 0s - loss: 0.0096 - val_loss: 0.0275
# Epoch 205/300
#  - 0s - loss: 0.0099 - val_loss: 0.0281
# Epoch 206/300
#  - 0s - loss: 0.0097 - val_loss: 0.0250
# Epoch 207/300
#  - 0s - loss: 0.0091 - val_loss: 0.0310
# Epoch 208/300
#  - 0s - loss: 0.0113 - val_loss: 0.0184
# Epoch 209/300
#  - 0s - loss: 0.0068 - val_loss: 0.0183
# Epoch 210/300
#  - 0s - loss: 0.0078 - val_loss: 0.0295
# Epoch 211/300
#  - 0s - loss: 0.0111 - val_loss: 0.0237
# Epoch 212/300
#  - 0s - loss: 0.0076 - val_loss: 0.0269
# Epoch 213/300
#  - 0s - loss: 0.0103 - val_loss: 0.0249
# Epoch 214/300
#  - 0s - loss: 0.0087 - val_loss: 0.0284
# Epoch 215/300
#  - 0s - loss: 0.0109 - val_loss: 0.0225
# Epoch 216/300
#  - 0s - loss: 0.0076 - val_loss: 0.0263
# Epoch 217/300
#  - 0s - loss: 0.0102 - val_loss: 0.0235
# Epoch 218/300
#  - 0s - loss: 0.0084 - val_loss: 0.0287
# Epoch 219/300
#  - 0s - loss: 0.0111 - val_loss: 0.0205
# Epoch 220/300
#  - 0s - loss: 0.0072 - val_loss: 0.0203
# Epoch 221/300
#  - 0s - loss: 0.0086 - val_loss: 0.0295
# Epoch 222/300
#  - 0s - loss: 0.0110 - val_loss: 0.0161
# Epoch 223/300
#  - 0s - loss: 0.0068 - val_loss: 0.0160
# Epoch 224/300
#  - 0s - loss: 0.0071 - val_loss: 0.0220
# Epoch 225/300
#  - 0s - loss: 0.0091 - val_loss: 0.0324
# Epoch 226/300
#  - 0s - loss: 0.0118 - val_loss: 0.0138
# Epoch 227/300
#  - 0s - loss: 0.0062 - val_loss: 0.0118
# Epoch 228/300
#  - 0s - loss: 0.0071 - val_loss: 0.0120
# Epoch 229/300
#  - 0s - loss: 0.0068 - val_loss: 0.0120
# Epoch 230/300
#  - 0s - loss: 0.0072 - val_loss: 0.0121
# Epoch 231/300
#  - 0s - loss: 0.0075 - val_loss: 0.0121
# Epoch 232/300
#  - 0s - loss: 0.0084 - val_loss: 0.0122
# Epoch 233/300
#  - 0s - loss: 0.0091 - val_loss: 0.0132
# Epoch 234/300
#  - 0s - loss: 0.0077 - val_loss: 0.0134
# Epoch 235/300
#  - 0s - loss: 0.0076 - val_loss: 0.0138
# Epoch 236/300
#  - 0s - loss: 0.0076 - val_loss: 0.0142
# Epoch 237/300
#  - 0s - loss: 0.0073 - val_loss: 0.0146
# Epoch 238/300
#  - 0s - loss: 0.0071 - val_loss: 0.0158
# Epoch 239/300
#  - 0s - loss: 0.0065 - val_loss: 0.0176
# Epoch 240/300
#  - 0s - loss: 0.0063 - val_loss: 0.0184
# Epoch 241/300
#  - 0s - loss: 0.0062 - val_loss: 0.0213
# Epoch 242/300
#  - 0s - loss: 0.0065 - val_loss: 0.0308
# Epoch 243/300
#  - 0s - loss: 0.0098 - val_loss: 0.0300
# Epoch 244/300
#  - 0s - loss: 0.0108 - val_loss: 0.0317
# Epoch 245/300
#  - 0s - loss: 0.0099 - val_loss: 0.0269
# Epoch 246/300
#  - 0s - loss: 0.0099 - val_loss: 0.0381
# Epoch 247/300
#  - 0s - loss: 0.0121 - val_loss: 0.0168
# Epoch 248/300
#  - 0s - loss: 0.0064 - val_loss: 0.0164
# Epoch 249/300
#  - 0s - loss: 0.0061 - val_loss: 0.0178
# Epoch 250/300
#  - 0s - loss: 0.0064 - val_loss: 0.0205
# Epoch 251/300
#  - 0s - loss: 0.0085 - val_loss: 0.0382
# Epoch 252/300
#  - 0s - loss: 0.0132 - val_loss: 0.0207
# Epoch 253/300
#  - 0s - loss: 0.0068 - val_loss: 0.0246
# Epoch 254/300
#  - 0s - loss: 0.0087 - val_loss: 0.0388
# Epoch 255/300
#  - 0s - loss: 0.0132 - val_loss: 0.0207
# Epoch 256/300
#  - 0s - loss: 0.0067 - val_loss: 0.0237
# Epoch 257/300
#  - 0s - loss: 0.0082 - val_loss: 0.0368
# Epoch 258/300
#  - 0s - loss: 0.0133 - val_loss: 0.0218
# Epoch 259/300
#  - 0s - loss: 0.0068 - val_loss: 0.0235
# Epoch 260/300
#  - 0s - loss: 0.0074 - val_loss: 0.0327
# Epoch 261/300
#  - 0s - loss: 0.0116 - val_loss: 0.0236
# Epoch 262/300
#  - 0s - loss: 0.0072 - val_loss: 0.0311
# Epoch 263/300
#  - 0s - loss: 0.0109 - val_loss: 0.0248
# Epoch 264/300
#  - 0s - loss: 0.0082 - val_loss: 0.0341
# Epoch 265/300
#  - 0s - loss: 0.0127 - val_loss: 0.0218
# Epoch 266/300
#  - 0s - loss: 0.0068 - val_loss: 0.0228
# Epoch 267/300
#  - 0s - loss: 0.0072 - val_loss: 0.0302
# Epoch 268/300
#  - 0s - loss: 0.0108 - val_loss: 0.0262
# Epoch 269/300
#  - 0s - loss: 0.0080 - val_loss: 0.0300
# Epoch 270/300
#  - 0s - loss: 0.0107 - val_loss: 0.0255
# Epoch 271/300
#  - 0s - loss: 0.0080 - val_loss: 0.0309
# Epoch 272/300
#  - 0s - loss: 0.0111 - val_loss: 0.0236
# Epoch 273/300
#  - 0s - loss: 0.0072 - val_loss: 0.0269
# Epoch 274/300
#  - 0s - loss: 0.0100 - val_loss: 0.0286
# Epoch 275/300
#  - 0s - loss: 0.0089 - val_loss: 0.0258
# Epoch 276/300
#  - 0s - loss: 0.0093 - val_loss: 0.0308
# Epoch 277/300
#  - 0s - loss: 0.0099 - val_loss: 0.0193
# Epoch 278/300
#  - 0s - loss: 0.0069 - val_loss: 0.0227
# Epoch 279/300
#  - 0s - loss: 0.0086 - val_loss: 0.0334
# Epoch 280/300
#  - 0s - loss: 0.0114 - val_loss: 0.0174
# Epoch 281/300
#  - 0s - loss: 0.0065 - val_loss: 0.0152
# Epoch 282/300
#  - 0s - loss: 0.0064 - val_loss: 0.0149
# Epoch 283/300
#  - 0s - loss: 0.0066 - val_loss: 0.0155
# Epoch 284/300
#  - 0s - loss: 0.0065 - val_loss: 0.0157
# Epoch 285/300
#  - 0s - loss: 0.0065 - val_loss: 0.0156
# Epoch 286/300
#  - 0s - loss: 0.0067 - val_loss: 0.0155
# Epoch 287/300
#  - 0s - loss: 0.0069 - val_loss: 0.0155
# Epoch 288/300
#  - 0s - loss: 0.0071 - val_loss: 0.0157
# Epoch 289/300
#  - 0s - loss: 0.0072 - val_loss: 0.0159
# Epoch 290/300
#  - 0s - loss: 0.0073 - val_loss: 0.0164
# Epoch 291/300
#  - 0s - loss: 0.0071 - val_loss: 0.0169
# Epoch 292/300
#  - 0s - loss: 0.0068 - val_loss: 0.0180
# Epoch 293/300
#  - 0s - loss: 0.0063 - val_loss: 0.0193
# Epoch 294/300
#  - 0s - loss: 0.0061 - val_loss: 0.0194
# Epoch 295/300
#  - 0s - loss: 0.0060 - val_loss: 0.0203
# Epoch 296/300
#  - 0s - loss: 0.0062 - val_loss: 0.0238
# Epoch 297/300
#  - 0s - loss: 0.0079 - val_loss: 0.0374
# Epoch 298/300
#  - 0s - loss: 0.0136 - val_loss: 0.0296
# Epoch 299/300
#  - 0s - loss: 0.0076 - val_loss: 0.0352
# Epoch 300/300
#  - 0s - loss: 0.0108 - val_loss: 0.0203

# %%
# plot history
pyplot.plot(history.history['loss'], label='train')
pyplot.plot(history.history['val_loss'], label='test')
pyplot.title('LSTM Loss')
pyplot.xlabel('epochs')
pyplot.ylabel('loss')
pyplot.legend()
pyplot.show()

# %%
pyplot.plot(inv_y, color = 'red', label = 'Real price')
pyplot.plot(inv_yhat, color= 'blue', label = 'predicted price')

pyplot.title('price prediction')
pyplot.xlabel('days')
pyplot.ylabel('price')
pyplot.legend()
pyplot.show()
